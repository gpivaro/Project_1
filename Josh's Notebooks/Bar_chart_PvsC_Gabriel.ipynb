# %%
# Dependencies and Setup
import os 
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
labels = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont', 'New Jersey',
          'New York', 'Pennsylvania', 'Illinois', 'Indiana', 'Michigan', 'Ohio', 'Wisconsin', 'Iowa',
          'Kansas', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'South Dakota', 'Delaware', 'Florida',
          'Georgia', 'Maryland', 'North Carolina', 'South Carolina', 'Virginia', 'West Virginia', 'Alabama',
          'Kentucky', 'Mississippi', 'Tennessee', 'Arkansas', 'Louisiana', 'Oklahoma', 'Texas', 'Arizona',
          'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico', 'Utah', 'Wyoming', 'California', 'Oregon', 
          'Washington', 'Alaska', 'Hawaii']

# %%
consump_path = os.path.join("..", "data", "state_consumption.csv")
consump_df= pd.read_csv(consump_path)
consump_df.head(63)
# Out:
#                    States  Residential  Unnamed: 2  Commercial  Unnamed: 4  \
# 0             New England       4020.0      3376.0      3854.0      4183.0
# 1             Connecticut       1172.0       944.0       992.0      1040.0
# 2                   Maine        371.0       331.0       291.0       308.0
# 3           Massachusetts       1642.0      1406.0      1773.0      2019.0
# 4           New Hampshire        395.0       323.0       335.0       352.0
# ..                    ...          ...         ...         ...         ...
# 58  Pacific Noncontiguous        388.0       366.0       401.0       465.0
# 59                 Alaska        140.0       131.0       187.0       209.0
# 60                 Hawaii        248.0       235.0       214.0       256.0
# 61             U.S. Total     131248.0    119519.0    108654.0    115338.0
# 62                    NaN          NaN         NaN         NaN         NaN
#
#     Industrial  Unnamed: 6  Transportation  Unnamed: 8  All Sectors_Mwh  \
# 0       1285.0      1210.0            33.0        38.0           9192.0
# 1        249.0       238.0             8.0        10.0           2421.0
# 2        244.0       143.0             0.0         0.0            907.0
# 3        465.0       498.0            25.0        26.0           3904.0
# 4        161.0       161.0             0.0         0.0            891.0
# ..         ...         ...             ...         ...              ...
# 58       365.0       408.0             0.0         0.0           1154.0
# 59       100.0        97.0             0.0         0.0            427.0
# 60       264.0       311.0             0.0         0.0            727.0
# 61     75225.0     80618.0           481.0       612.0         315608.0
# 62         NaN         NaN             NaN         NaN              NaN
#
#     Unnamed: 10
# 0        8807.0
# 1        2232.0
# 2         782.0
# 3        3949.0
# 4         836.0
# ..          ...
# 58       1239.0
# 59        436.0
# 60        803.0
# 61     316087.0
# 62          NaN
#
# [63 rows x 11 columns]

# %%
consuption = []

for row in range(len(labels)):
    consuption.append(float(consump_df['All Sectors_Mwh'].loc[consump_df['States']==labels[row]]))

consuption_all_sectors_df = pd.DataFrame({'States':labels,'All Sectors_Mwh':consuption})
consuption_all_sectors_df = consuption_all_sectors_df.sort_values(by=['All Sectors_Mwh'],ascending=False)

# %%
cost_chart = consuption_all_sectors_df.plot.bar(x='States', y='All Sectors_Mwh', rot=90, color='b',figsize=(11,6))
cost_chart.set_title("Electricity Consumption by State")
cost_chart.set_xlabel("State")
# plt.legend('')
plt.gca().get_legend().remove()
cost_chart.set_ylabel("MWh")
plt.savefig("Fig_Consumption_State.png")

# %%
price_path = os.path.join("..", "data", "state_price.csv")
price_df= pd.read_csv(price_path)
price_df.head(63)
# Out:
#                    States  Residential  Unnamed: 2  Commercial  Unnamed: 4  \
# 0             New England        20.47       21.20       15.39       16.35
# 1             Connecticut        21.73       23.10       16.51       17.60
# 2                   Maine        16.91       18.18       12.64       12.40
# 3           Massachusetts        21.01       21.36       15.18       16.53
# 4           New Hampshire        19.00       20.34       15.26       15.65
# ..                    ...          ...         ...         ...         ...
# 58  Pacific Noncontiguous        27.16       29.26       23.97       25.56
# 59                 Alaska        23.85       23.51       20.45       20.45
# 60                 Hawaii        29.03       32.45       27.04       29.72
# 61             U.S. Total        13.28       13.36       10.96       10.88
# 62                    NaN          NaN         NaN         NaN         NaN
#
#     Industrial  Unnamed: 6 Transportation Unnamed: 8  \
# 0        12.38       13.11           7.23       8.91
# 1        13.03       13.85          10.67      16.39
# 2         8.53        9.24             --         --
# 3        13.87       14.25           5.26        5.2
# 4        12.72       12.66             --         --
# ..         ...         ...            ...        ...
# 58       21.06       23.80             --         --
# 59       17.55       17.06             --         --
# 60       22.40       25.90             --         --
# 61        6.95        6.91          10.44      10.06
# 62         NaN         NaN            NaN        NaN
#
#     All Sectors_cents per Kwh  Unnamed: 10
# 0                       17.16        17.73
# 1                       18.66        19.52
# 2                       13.28        14.26
# 3                       17.41        17.89
# 4                       16.46        16.88
# ..                        ...          ...
# 58                      24.13        26.07
# 59                      20.89        20.62
# 60                      26.03        29.04
# 61                      10.97        10.80
# 62                        NaN          NaN
#
# [63 rows x 11 columns]

# %%
state_df = pd.merge(price_df, consump_df, on = ['States'], how = 'outer')

state_df.head(64)
# Out:
#            States  Residential_x  Unnamed: 2_x  Commercial_x  Unnamed: 4_x  \
# 0     New England          20.47         21.20         15.39         16.35
# 1     Connecticut          21.73         23.10         16.51         17.60
# 2           Maine          16.91         18.18         12.64         12.40
# 3   Massachusetts          21.01         21.36         15.18         16.53
# 4   New Hampshire          19.00         20.34         15.26         15.65
# ..            ...            ...           ...           ...           ...
# 59         Alaska          23.85         23.51         20.45         20.45
# 60         Hawaii          29.03         32.45         27.04         29.72
# 61     U.S. Total          13.28         13.36         10.96         10.88
# 62            NaN            NaN           NaN           NaN           NaN
# 63            NaN            NaN           NaN           NaN           NaN
#
#     Industrial_x  Unnamed: 6_x Transportation_x Unnamed: 8_x  \
# 0          12.38         13.11             7.23         8.91
# 1          13.03         13.85            10.67        16.39
# 2           8.53          9.24               --           --
# 3          13.87         14.25             5.26          5.2
# 4          12.72         12.66               --           --
# ..           ...           ...              ...          ...
# 59         17.55         17.06               --           --
# 60         22.40         25.90               --           --
# 61          6.95          6.91            10.44        10.06
# 62           NaN           NaN              NaN          NaN
# 63           NaN           NaN              NaN          NaN
#
#     All Sectors_cents per Kwh  ...  Residential_y  Unnamed: 2_y  Commercial_y  \
# 0                       17.16  ...         4020.0        3376.0        3854.0
# 1                       18.66  ...         1172.0         944.0         992.0
# 2                       13.28  ...          371.0         331.0         291.0
# 3                       17.41  ...         1642.0        1406.0        1773.0
# 4                       16.46  ...          395.0         323.0         335.0
# ..                        ...  ...            ...           ...           ...
# 59                      20.89  ...          140.0         131.0         187.0
# 60                      26.03  ...          248.0         235.0         214.0
# 61                      10.97  ...       131248.0      119519.0      108654.0
# 62                        NaN  ...            NaN           NaN           NaN
# 63                        NaN  ...            NaN           NaN           NaN
#
#     Unnamed: 4_y  Industrial_y  Unnamed: 6_y  Transportation_y  Unnamed: 8_y  \
# 0         4183.0        1285.0        1210.0              33.0          38.0
# 1         1040.0         249.0         238.0               8.0          10.0
# 2          308.0         244.0         143.0               0.0           0.0
# 3         2019.0         465.0         498.0              25.0          26.0
# 4          352.0         161.0         161.0               0.0           0.0
# ..           ...           ...           ...               ...           ...
# 59         209.0         100.0          97.0               0.0           0.0
# 60         256.0         264.0         311.0               0.0           0.0
# 61      115338.0       75225.0       80618.0             481.0         612.0
# 62           NaN           NaN           NaN               NaN           NaN
# 63           NaN           NaN           NaN               NaN           NaN
#
#     All Sectors_Mwh  Unnamed: 10_y
# 0            9192.0         8807.0
# 1            2421.0         2232.0
# 2             907.0          782.0
# 3            3904.0         3949.0
# 4             891.0          836.0
# ..              ...            ...
# 59            427.0          436.0
# 60            727.0          803.0
# 61         315608.0       316087.0
# 62              NaN            NaN
# 63              NaN            NaN
#
# [64 rows x 21 columns]

# %%
state_group = state_df.groupby('States')
state_price = state_group["All Sectors_cents per Kwh"].mean()
state_price
# Out:
# States
# Alabama               10.38
# Alaska                20.89
# Arizona               11.23
# Arkansas               8.70
# California            18.78
#                       ...
# West North Central    10.71
# West South Central     8.50
# West Virginia          8.80
# Wisconsin             11.69
# Wyoming                8.54
# Name: All Sectors_cents per Kwh, Length: 63, dtype: float64

# %%
plt.figure(figsize=(15,6))
state_price = state_price.sort_values(ascending=False)
cost_chart = state_price.plot(kind='bar')
cost_chart.set_xlabel("State")
cost_chart.set_ylabel("Price (Cents Per KWh)")

plt.show()

# %%
state_group = state_df.groupby('States')
state_cons = state_group["All Sectors_Mwh"].mean()
state_cons
# Out:
# States
# Alabama                7192.0
# Alaska                  427.0
# Arizona                7832.0
# Arkansas               3735.0
# California            21272.0
#                        ...
# West North Central    24852.0
# West South Central    54073.0
# West Virginia          2477.0
# Wisconsin              5724.0
# Wyoming                1139.0
# Name: All Sectors_Mwh, Length: 63, dtype: float64

# %%
plt.figure(figsize=(15,6))
state_cons = state_cons.sort_values(ascending=False)
cost_chart = state_cons.plot(kind='bar')
cost_chart.set_xlabel("State")
cost_chart.set_ylabel("MWh")

plt.show()

# %%
labels = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont', 'New Jersey',
          'New York', 'Pennsylvania', 'Illinois', 'Indiana', 'Michigan', 'Ohio', 'Wisconsin', 'Iowa',
          'Kansas', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'South Dakota', 'Delaware', 'Florida',
          'Georgia', 'Maryland', 'North Carolina', 'South Carolina', 'Virginia', 'West Virginia', 'Alabama',
          'Kentucky', 'Mississippi', 'Tennessee', 'Arkansas', 'Louisiana', 'Oklahoma', 'Texas', 'Arizona',
          'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico', 'Utah', 'Wyoming', 'California', 'Oregon', 
          'Washington', 'Alaska', 'Hawaii']


price_means = [ ]
consump_means = [ ]

x = np.arange(len(labels)) 
width = 0.15  

plt.figure(figsize=(15,6))
fig, ax = plt.subplots()
rects1 = ax.bar(['All Sectors_cents per Kwh'], width, label='Price')
rects2 = ax.bar(['All Sectors_Mwh'], width, label='Consumption')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Consumption')
ax.set_title('Price VS Consumption by State')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
ax2.set_ylabel("Price (Cents per KWh)")

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

               
plt.show()
